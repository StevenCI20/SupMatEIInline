# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
nameP="AngiografiaR"
nameEI="EI"
nameIl="Inline"
nameR="PData"
Name1="Contrast"
Name2="CNR"
Name3="Doses"

# %%
V=np.array([28,38,48,58,68,78])

# %%
PDIlEI1=np.array([73.15,71.6,69.66,67.52,64.85,62.2])
PDIlEI2=np.array([70.0,67.56,66.21,64.13,61.83,59.14])
PDIlEI3=np.array([62.31,59.43,58.1,56.15,54.23,51.61])

# %%
CAIl1=np.array([0.00082,0.00080,0.00078,0.00080,0.00076,0.00080])
CAIl2=np.array([0.00087,0.00082,0.00078,0.00082,0.00077,0.00080])
CAIl3=np.array([0.00093,0.00082,0.00078,0.00085,0.00083,0.00082])
CAEI1=np.array([0.00092,0.00083,0.00078,0.00077,0.00074,0.00072])
CAEI2=np.array([0.00098,0.00087,0.00078,0.00078,0.00077,0.00081])
CAEI3=np.array([0.00103,0.00092,0.00085,0.00085,0.00083,0.00081])

# %%
CNRAIl1=np.array([1.91,2.00,1.99,1.89,1.88,1.79])
CNRAIl2=np.array([2.75,2.75,2.81,2.71,2.75,2.49])
CNRAIl3=np.array([2.92,3.16,3.16,3.13,3.29,3.18])
CNRAEI1=np.array([0.76,0.74,0.78,0.87,0.97,1.01])
CNRAEI2=np.array([1.41,1.46,1.47,1.46,1.66,1.67])
CNRAEI3=np.array([2.00,2.13,2.11,2.11,2.21,2.28])

# %%
CPSIl1=np.array([0.001,0.00072,0.00052,0.00051,0.00048,0.00039])
CPSIl2=np.array([0.00094,0.00071,0.00064,0.00051,0.00044,0.00039])
CPSIl3=np.array([0.00094,0.00075,0.00058,0.00051,0.00046,0.00039])
CPSEI1=np.array([0.0009,0.00072,0.00052,0.00051,0.00048,0.00039])
CPSEI2=np.array([0.00087,0.00071,0.00052,0.00045,0.00041,0.00039])
CPSEI3=np.array([0.00082,0.00063,0.00051,0.00048,0.00043,0.00037])

# %%
CNRPSIl1=np.array([1.74,1.62,1.48,1.28,1.40,1.17])
CNRPSIl2=np.array([2.33,2.20,2.18,1.89,1.81,1.73])
CNRPSIl3=np.array([2.76,2.58,2.21,2.00,1.88,1.68])
CNRPSEI1=np.array([0.62,0.68,0.65,0.67,0.73,0.66])
CNRPSEI2=np.array([1.06,1.18,1.08,0.92,1.03,1.03])
CNRPSEI3=np.array([1.45,1.45,1.40,1.22,1.25,1.15])

# %%
CPIIl1=np.array([0.00215,0.0016,0.0012,0.00105,0.00092,0.00084])
CPIIl2=np.array([0.00215,0.0016,0.00125,0.00109,0.00092,0.00086])
CPIIl3=np.array([0.00225,0.00165,0.00129,0.00113,0.00096,0.00086])
CPIEI1=np.array([0.00205,0.0015,0.0011,0.00101,0.00081,0.00075])
CPIEI2=np.array([0.002,0.0015,0.00117,0.00096,0.00082,0.00071])
CPIEI3=np.array([0.0019,0.0015,0.00125,0.00101,0.00087,0.00075])

# %%
CNRPIIl1=np.array([4.08,3.87,3.29,2.75,2.64,2.50])
CNRPIIl2=np.array([5.88,4.44,4.58,3.98,3.72,3.31])
CNRPIIl3=np.array([7.01,5.87,5.12,4.48,3.95,3.50])
CNRPIEI1=np.array([1.60,1.55,1.34,1.27,1.32,1.24])
CNRPIEI2=np.array([2.57,2.57,2.28,1.94,1.99,1.89])
CNRPIEI3=np.array([3.42,3.24,3.06,2.65,2.54,2.25])

# %%
CPCIl1=np.array([0.00356,0.00265,0.002,0.0017,0.0015,0.00137])
CPCIl2=np.array([0.00365,0.00265,0.00213,0.00182,0.00153,0.00137])
CPCIl3=np.array([0.00365,0.0028,0.00213,0.00182,0.00159,0.00142])
CPCEI1=np.array([0.0034,0.00245,0.00165,0.00145,0.0013,0.001])
CPCEI2=np.array([0.00329,0.00255,0.00183,0.0016,0.0013,0.00104])
CPCEI3=np.array([0.00325,0.0025,0.00191,0.00161,0.00137,0.0012])

# %%
CNRPCIl1=np.array([7.15,6.47,5.40,4.50,4.15,3.84])
CNRPCIl2=np.array([10.09,8.87,7.68,6.58,5.80,5.42])
CNRPCIl3=np.array([11.51,10.31,8.60,6.99,6.49,5.73])
CNRPCEI1=np.array([2.62,2.48,2.16,2.00,1.91,1.83])
CNRPCEI2=np.array([4.41,4.23,3.52,3.12,3.08,2.86])
CNRPCEI3=np.array([6.01,5.52,4.84,4.20,3.96,3.53])

# %%
fig,ax=plt.subplots()
plt.plot(V,CAIl1*1000, '--^',label='$M_{low}$', color="blue")
plt.plot(V,CAIl2*1000, '--^',label='$M_{medium}$', color="red")
plt.plot(V,CAIl3*1000, '--^',label='$M_{high}$', color="green")
plt.axhline(y=0.00092*1000, xmin=0, xmax=80,linestyle="-.", color="brown")
plt.text(55, 0.001*1000, "Inline XPCI", fontsize=16, color='black', fontweight="bold")
plt.text(55, 0.00097*1000, "Plaque-free region", fontsize=16, color='black')
plt.text(70, 0.000895*1000, "ET-HL", fontsize=14, color='brown', fontweight="bold")
plt.ylabel("Contrast (mm)",fontsize=14)
plt.xlabel("Voltage (kVp)",fontsize=14)
plt.ylim(0.0007*1000,0.00105*1000)
plt.grid()
plt.legend(bbox_to_anchor=(0.97, -0.17),mode = "Expand", ncol=3,fontsize=16)
#plt.savefig(nameP+"/"+nameIl+"/"+nameR+"/"+Name1+nameIl+"A.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)

# %%
fig,ax=plt.subplots()
plt.plot(V,CAEI1*1000, '--^',label='$M_{low}$', color="blue")
plt.plot(V,CAEI2*1000, '--^',label='$M_{medium}$', color="red")
plt.plot(V,CAEI3*1000, '--^',label='$M_{high}$', color="green")
plt.axhline(y=0.00092*1000, xmin=0, xmax=80,linestyle="-.", color="brown")
plt.text(55, 0.001*1000, "EISM", fontsize=16, color='black', fontweight="bold")
plt.text(55, 0.00097*1000, "Plaque-free region", fontsize=16, color='black')
plt.text(70, 0.000895*1000, "ET-HL", fontsize=14, color='brown', fontweight="bold")
plt.ylabel("Contrast (mm)",fontsize=14)
plt.xlabel("Voltage (kVp)",fontsize=14)
plt.ylim(0.0007*1000,0.00105*1000)
plt.grid()
plt.legend(bbox_to_anchor=(0.97, -0.17),mode = "Expand", ncol=3,fontsize=16)
#plt.savefig(nameP+"/"+nameEI+"/"+nameR+"/"+Name1+nameEI+"A.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)

# %%
fig,ax=plt.subplots()
plt.plot(V,CNRAIl1, '--^',label='$M_{low}$', color="blue")
plt.plot(V,CNRAIl2, '--^',label='$M_{medium}$', color="red")
plt.plot(V,CNRAIl3, '--^',label='$M_{high}$', color="green")
plt.text(55, 1., "Inline XPCI", fontsize=16, color='black', fontweight="bold")
plt.text(55, 0.75, "Plaque-free region", fontsize=16, color='black')
plt.ylabel("CNR",fontsize=14)
plt.xlabel("Voltage (kVp)",fontsize=14)
plt.ylim(0,3.5)
plt.grid()
plt.legend(bbox_to_anchor=(0.97, -0.17),mode = "Expand", ncol=3,fontsize=16)
#plt.savefig(nameP+"/"+nameIl+"/"+nameR+"/"+Name2+nameIl+"A.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)

# %%
fig,ax=plt.subplots()
plt.plot(V,CNRAEI1, '--^',label='$M_{low}$', color="blue")
plt.plot(V,CNRAEI2, '--^',label='$M_{medium}$', color="red")
plt.plot(V,CNRAEI3, '--^',label='$M_{high}$', color="green")
plt.text(55, 3., "EISM", fontsize=16, color='black', fontweight="bold")
plt.text(55, 2.75, "Plaque-free region", fontsize=16, color='black')
plt.ylabel("CNR",fontsize=14)
plt.xlabel("Voltage (kVp)",fontsize=14)
plt.ylim(0,3.5)
plt.grid()
plt.legend(bbox_to_anchor=(0.97, -0.17),mode = "Expand", ncol=3,fontsize=16)
#plt.savefig(nameP+"/"+nameEI+"/"+nameR+"/"+Name2+nameEI+"A.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)

# %%
fig,ax=plt.subplots()
plt.plot(V,CPSIl1*1000, '--^',label='$M_{low}$'+": Soft", color="blue")
plt.plot(V,CPIIl1*1000, '--o',label='$M_{low}$'+": Inte.", color="blue")
plt.plot(V,CPCIl1*1000, '--s',label='$M_{low}$'+": Calc.", color="blue")
plt.plot(V,CPSIl2*1000, '--^',label='$M_{medium}$'+": Soft", color="red")
plt.plot(V,CPIIl2*1000, '--o',label='$M_{medium}$'+": Inte.", color="red")
plt.plot(V,CPCIl2*1000, '--s',label='$M_{medium}$'+": Calc.", color="red")
plt.plot(V,CPSIl3*1000, '--^',label='$M_{high}$'+": Soft", color="green")
plt.plot(V,CPIIl3*1000, '--o',label='$M_{high}$'+": Inte.", color="green")
plt.plot(V,CPCIl3*1000, '--s',label='$M_{high}$'+": Calc.", color="green")
plt.text(55, 0.0033*1000, "Inline XPCI", fontsize=16, color='black', fontweight="bold")
plt.text(55, 0.0030*1000, "Plaque region", fontsize=16, color='black')
plt.ylabel("Contrast (mm)",fontsize=14)
plt.xlabel("Voltage (kVp)",fontsize=14)
plt.ylim(0,0.0037*1000)
plt.grid()
plt.legend(bbox_to_anchor=(1.1, -0.17),mode = "Expand", ncol=3,fontsize=14.5)
#plt.savefig(nameP+"/"+nameIl+"/"+nameR+"/"+Name1+nameIl+".png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)

# %%
fig,ax=plt.subplots()
plt.plot(V,CNRPSIl1, '--^',label="Soft", color="blue")
plt.plot(V,CNRPIIl1, '--o',label="Inte.", color="blue")
plt.plot(V,CNRPCIl1, '--s',label="Calc.", color="blue")
plt.text(60, 6.6, "Inline XPCI", fontsize=16, color='black', fontweight="bold")
plt.text(60, 6.1, '$M_{low}$', fontsize=16, color='black')
plt.ylabel("CNR",fontsize=14)
plt.xlabel("Voltage (kVp)",fontsize=14)
plt.grid()
plt.legend(bbox_to_anchor=(0.93, -0.17),mode = "Expand", ncol=3,fontsize=16)
#plt.savefig(nameP+"/"+nameIl+"/"+nameR+"/"+Name2+nameIl+"1.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)

# %%
fig,ax=plt.subplots()
plt.plot(V,CNRPSIl2, '--^',label="Soft", color="red")
plt.plot(V,CNRPIIl2, '--o',label="Inte.", color="red")
plt.plot(V,CNRPCIl2, '--s',label="Calc.", color="red")
plt.text(60, 9.5, "Inline XPCI", fontsize=16, color='black', fontweight="bold")
plt.text(60, 8.7, '$M_{medium}$', fontsize=16, color='black')
plt.ylabel("CNR",fontsize=14)
plt.xlabel("Voltage (kVp)",fontsize=14)
plt.grid()
plt.legend(bbox_to_anchor=(0.93, -0.17),mode = "Expand", ncol=3,fontsize=16)
#plt.savefig(nameP+"/"+nameIl+"/"+nameR+"/"+Name2+nameIl+"2.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)

# %%
fig,ax=plt.subplots()
plt.plot(V,CNRPSIl3, '--^',label="Soft", color="green")
plt.plot(V,CNRPIIl3, '--o',label="Inte.", color="green")
plt.plot(V,CNRPCIl3, '--s',label="Calc.", color="green")
plt.text(60, 10.5, "Inline XPCI", fontsize=16, color='black', fontweight="bold")
plt.text(60, 9.5, '$M_{high}$', fontsize=16, color='black')
plt.ylabel("CNR",fontsize=14)
plt.xlabel("Voltage (kVp)",fontsize=14)
plt.grid()
plt.legend(bbox_to_anchor=(0.93, -0.17),mode = "Expand", ncol=3,fontsize=16)
#plt.savefig(nameP+"/"+nameIl+"/"+nameR+"/"+Name2+nameIl+"3.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)

# %%
fig,ax=plt.subplots()
plt.plot(V,CPSEI1*1000, '--^',label='$M_{low}$'+": Soft", color="blue")
plt.plot(V,CPIEI1*1000, '--o',label='$M_{low}$'+": Inte.", color="blue")
plt.plot(V,CPCEI1*1000, '--s',label='$M_{low}$'+": Calc.", color="blue")
plt.plot(V,CPSEI2*1000, '--^',label='$M_{medium}$'+": Soft", color="red")
plt.plot(V,CPIEI2*1000, '--o',label='$M_{medium}$'+": Inte.", color="red")
plt.plot(V,CPCEI2*1000, '--s',label='$M_{medium}$'+": Calc.", color="red")
plt.plot(V,CPSEI3*1000, '--^',label='$M_{high}$'+": Soft", color="green")
plt.plot(V,CPIEI3*1000, '--o',label='$M_{high}$'+": Inte.", color="green")
plt.plot(V,CPCEI3*1000, '--s',label='$M_{high}$'+": Calc.", color="green")
plt.text(55, 0.0033*1000, "EISM", fontsize=16, color='black', fontweight="bold")
plt.text(55, 0.0030*1000, "Plaque region", fontsize=16, color='black')
plt.ylabel("Contrast (mm)",fontsize=14)
plt.xlabel("Voltage (kVp)",fontsize=14)
plt.ylim(0,0.0037*1000)
plt.grid()
plt.legend(bbox_to_anchor=(1.1, -0.17),mode = "Expand", ncol=3,fontsize=14.5)
#plt.savefig(nameP+"/"+nameEI+"/"+nameR+"/"+Name1+nameEI+".png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)

# %%
fig,ax=plt.subplots()
plt.plot(V,CNRPSEI1, '--^',label="Soft", color="blue")
plt.plot(V,CNRPIEI1, '--o',label="Inte.", color="blue")
plt.plot(V,CNRPCEI1, '--s',label="Calc.", color="blue")
plt.text(60, 2.4, "EISM", fontsize=16, color='black', fontweight="bold")
plt.text(60, 2.21, '$M_{low}$', fontsize=16, color='black')
plt.ylabel("CNR",fontsize=14)
plt.xlabel("Voltage (kVp)",fontsize=14)
plt.grid()
plt.legend(bbox_to_anchor=(0.93, -0.17),mode = "Expand", ncol=3,fontsize=16)
#plt.savefig(nameP+"/"+nameEI+"/"+nameR+"/"+Name2+nameEI+"1.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)

# %%
fig,ax=plt.subplots()
plt.plot(V,CNRPSEI2, '--^',label="Soft", color="red")
plt.plot(V,CNRPIEI2, '--o',label="Inte.", color="red")
plt.plot(V,CNRPCEI2, '--s',label="Calc.", color="red")
plt.text(60, 4.1, "EISM", fontsize=16, color='black', fontweight="bold")
plt.text(60, 3.7, '$M_{medium}$', fontsize=16, color='black')
plt.ylabel("CNR",fontsize=14)
plt.xlabel("Voltage (kVp)",fontsize=14)
plt.grid()
plt.legend(bbox_to_anchor=(0.93, -0.17),mode = "Expand", ncol=3,fontsize=16)
#plt.savefig(nameP+"/"+nameEI+"/"+nameR+"/"+Name2+nameEI+"2.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)

# %%
fig,ax=plt.subplots()
plt.plot(V,CNRPSEI3, '--^',label="Soft", color="green")
plt.plot(V,CNRPIEI3, '--o',label="Inte.", color="green")
plt.plot(V,CNRPCEI3, '--s',label="Calc.", color="green")
plt.text(60, 5.5, "EISM", fontsize=16, color='black', fontweight="bold")
plt.text(60, 5, '$M_{high}$', fontsize=16, color='black')
plt.ylabel("CNR",fontsize=14)
plt.xlabel("Voltage (kVp)",fontsize=14)
plt.grid()
plt.legend(bbox_to_anchor=(0.93, -0.17),mode = "Expand", ncol=3,fontsize=16)
#plt.savefig(nameP+"/"+nameEI+"/"+nameR+"/"+Name2+nameEI+"3.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)

# %%
fig,ax=plt.subplots()
plt.plot(V,PDIlEI1, '--o',label='$M_{low}$', color="blue")
plt.plot(V,PDIlEI2, '--s',label='$M_{medium}$', color="red")
plt.plot(V,PDIlEI3, '--^',label='$M_{high}$', color="green")
plt.ylabel("Percentage difference in Dose (%)",fontsize=14)
plt.xlabel("Voltage (kVp)",fontsize=14)
plt.grid()
plt.ylim(50,80)
plt.legend(bbox_to_anchor=(0.93, -0.17),mode = "Expand", ncol=3,fontsize=16)
#plt.savefig(nameP+"/"+nameEI+"/"+nameR+"/"+Name3+nameEI+"DP.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
